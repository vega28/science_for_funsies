# %% [markdown]
# ## Solar Photon Simulation
# Author: Kelsi Flatland <br>
# Date created: 2021-06-17 <br>
# Last updated: 2021-06-17 <br>
# Description: An exploration of the path of a photon from the center of the sun to the surface. <br>
# Attributions: [NASA Space Math], [Open Source Physics]
#
# [NASA Space Math]: <https://spacemath.gsfc.nasa.gov/weekly/6Page102.pdf>
# [Open Source Physics]: <https://www.compadre.org/osp/items/detail.cfm?ID=11349>

# %% [markdown]
# ### Set up environment and dependencies

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# ### Background
# A photon created in the center of the sun during thermonuclear fusion is not immediately released into space - it must travel out through all the plasma and shenanigans that make up the sun. This script aims to illustrate the path of a photon from the core out into space!
#
# The path a photon takes will be dependent on the density of that part of the sun (since it will keep running into atoms and bouncing around), so let's first take a look at the density of the sun as a function of radius.
#
# A [polynomial approximation] of the solar density profile is: <br>
# $$
# D(r) = 519r^4 - 1630r^3 + 1844r^2 - 889r + 155
# $$
#
# Here we have two different views of the same density profile:
#
# [polynomial approximation]: <https://spacemath.gsfc.nasa.gov/weekly/6Page102.pdf>

# %%
n = 100
r = np.arange(0.0, 1.0, (1/n))
rho = 519*r**4 - 1630*r**3 + 1844*r**2 - 889*r + 155

fig, ax = plt.subplots()
ax.plot(r, rho)

ax.set(xlabel='fraction of radius of sun', ylabel='density (g/cm^3)',
    title='Solar Density Profile')
ax.grid()

plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(r, rho)

ax.semilogy()
ax.set(xlabel='fraction of radius of sun', ylabel='density (g/cm^3)',
    title='Solar Density Profile (log plot)')
ax.grid()

plt.show()
